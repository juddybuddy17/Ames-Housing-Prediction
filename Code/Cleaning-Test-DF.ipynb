# %% [markdown]
# # Cleaning Test Data For Predictions

# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# # Read / Explore / Clean

# %%
test = pd.read_csv('../Data/test.csv')
test.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# ...

# %%
test.shape
# Out:
# (878, 80)

# %%
test.dtypes
# Out:
# Id                int64
# PID               int64
# MS SubClass       int64
# MS Zoning        object
# Lot Frontage    float64
#                  ...
# Misc Feature     object
# Misc Val          int64
# Mo Sold           int64
# Yr Sold           int64
# Sale Type        object
# Length: 80, dtype: object

# %%
test.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count   878.000000  8.780000e+02   878.000000    718.000000     878.000000
# mean   1444.749431  7.162867e+08    58.268793     69.545961   10307.033030
# std     850.838263  1.889103e+08    42.235407     23.533945   10002.674602
# min       2.000000  5.263021e+08    20.000000     21.000000    1477.000000
# 25%     692.250000  5.284841e+08    20.000000     59.000000    7297.250000
# 50%    1433.000000  5.354542e+08    50.000000     68.000000    9446.000000
# 75%    2197.500000  9.071904e+08    70.000000     80.000000   11589.000000
# max    2928.000000  1.007100e+09   190.000000    182.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count    878.000000    878.000000   878.000000      878.000000    877.000000
# mean       6.050114      5.566059  1970.492027     1984.417995    106.236032
# ...

# %%
test.columns = test.columns.str.lower().str.replace(' ','_')
test.head(0)
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ##### Test_1

# %%
test_1 = test.iloc[:,0:15]
test_1.head()
# Out:
#      id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   alley lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   condition_1
# 0        Norm
# 1        Norm
# 2        Norm
# ...

# %%
test_1.shape
# Out:
# (878, 15)

# %%
test_1.dtypes
# Out:
# id                int64
# pid               int64
# ms_subclass       int64
# ms_zoning        object
# lot_frontage    float64
# lot_area          int64
# street           object
# alley            object
# lot_shape        object
# land_contour     object
# utilities        object
# lot_config       object
# land_slope       object
# neighborhood     object
# condition_1      object
# dtype: object

# %%
test_1.describe(include ='all')
# Out:
#                  id           pid  ms_subclass ms_zoning  lot_frontage  \
# count    878.000000  8.780000e+02   878.000000       878    718.000000
# unique          NaN           NaN          NaN         6           NaN
# top             NaN           NaN          NaN        RL           NaN
# freq            NaN           NaN          NaN       674           NaN
# mean    1444.749431  7.162867e+08    58.268793       NaN     69.545961
# std      850.838263  1.889103e+08    42.235407       NaN     23.533945
# min        2.000000  5.263021e+08    20.000000       NaN     21.000000
# 25%      692.250000  5.284841e+08    20.000000       NaN     59.000000
# 50%     1433.000000  5.354542e+08    50.000000       NaN     68.000000
# 75%     2197.500000  9.071904e+08    70.000000       NaN     80.000000
# max     2928.000000  1.007100e+09   190.000000       NaN    182.000000
#
#              lot_area street alley lot_shape land_contour utilities  \
# ...

# %%
test_1.isna().sum()
# Out:
# id                0
# pid               0
# ms_subclass       0
# ms_zoning         0
# lot_frontage    160
# lot_area          0
# street            0
# alley           820
# lot_shape         0
# land_contour      0
# utilities         0
# lot_config        0
# land_slope        0
# neighborhood      0
# condition_1       0
# dtype: int64

# %%
test[['lot_frontage', 'alley']] = test[['lot_frontage', 'alley']].fillna(0)

# %%
test[['lot_frontage', 'alley']].isna().sum()
# Out:
# lot_frontage    0
# alley           0
# dtype: int64

# %%
# make 'street' a binary value
test['street'] = test['street'].replace({'Pave':0, 'Grvl':1})
test['street'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: street, dtype: int64

# %% [markdown]
# ##### Test_2

# %%
test_2 = test.iloc[:,15:30]
test_2.head()
# Out:
#   condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 0        Norm    2fmCon      2Story             6             8        1910
# 1        Norm    Duplex      1Story             5             4        1977
# 2        Norm      1Fam      2Story             7             5        2006
# 3        Norm      1Fam      1Story             5             6        1923
# 4        Norm      1Fam      1Story             6             5        1963
#
#    year_remod/add roof_style roof_matl exterior_1st exterior_2nd mas_vnr_type  \
# 0            1950      Gable   CompShg      AsbShng      AsbShng         None
# 1            1977      Gable   CompShg      Plywood      Plywood         None
# 2            2006      Gable   CompShg      VinylSd      VinylSd         None
# 3            2006      Gable   CompShg      Wd Sdng      Wd Sdng         None
# 4            1963      Gable   CompShg      Plywood      Plywood      BrkFace
#
#    mas_vnr_area exter_qual exter_cond
# ...

# %%
test_2.shape
# Out:
# (878, 15)

# %%
test_2.dtypes
# Out:
# condition_2        object
# bldg_type          object
# house_style        object
# overall_qual        int64
# overall_cond        int64
# year_built          int64
# year_remod/add      int64
# roof_style         object
# roof_matl          object
# exterior_1st       object
# exterior_2nd       object
# mas_vnr_type       object
# mas_vnr_area      float64
# exter_qual         object
# exter_cond         object
# dtype: object

# %%
test_2.describe(include='all')
# Out:
#        condition_2 bldg_type house_style  overall_qual  overall_cond  \
# count          878       878         878    878.000000    878.000000
# unique           3         5           8           NaN           NaN
# top           Norm      1Fam      1Story           NaN           NaN
# freq           875       724         422           NaN           NaN
# mean           NaN       NaN         NaN      6.050114      5.566059
# std            NaN       NaN         NaN      1.369065      1.128903
# min            NaN       NaN         NaN      2.000000      1.000000
# 25%            NaN       NaN         NaN      5.000000      5.000000
# 50%            NaN       NaN         NaN      6.000000      5.000000
# 75%            NaN       NaN         NaN      7.000000      6.000000
# max            NaN       NaN         NaN     10.000000      9.000000
#
#          year_built  year_remod/add roof_style roof_matl exterior_1st  \
# ...

# %%
test_2.isna().sum()
# Out:
# condition_2       0
# bldg_type         0
# house_style       0
# overall_qual      0
# overall_cond      0
# year_built        0
# year_remod/add    0
# roof_style        0
# roof_matl         0
# exterior_1st      0
# exterior_2nd      0
# mas_vnr_type      1
# mas_vnr_area      1
# exter_qual        0
# exter_cond        0
# dtype: int64

# %%
test['mas_vnr_type'] = test['mas_vnr_type'].fillna('None')

# %%
test['mas_vnr_area'] = test['mas_vnr_area'].fillna(0)

# %%
test[['mas_vnr_area', 'mas_vnr_type']].isna().sum()
# Out:
# mas_vnr_area    0
# mas_vnr_type    0
# dtype: int64

# %% [markdown]
# ##### Test_3

# %%
test_3=test.iloc[:,30:45]
test_3.head()
# Out:
#   foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 0      Stone        Fa        TA            No            Unf             0
# 1     CBlock        Gd        TA            No            Unf             0
# 2      PConc        Gd        Gd            Av            GLQ           554
# 3     CBlock        TA        TA            No            Unf             0
# 4     CBlock        Gd        TA            No            BLQ           609
#
#   bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc  \
# 0            Unf             0         1020           1020    GasA         Gd
# 1            Unf             0         1967           1967    GasA         TA
# 2            Unf             0          100            654    GasA         Ex
# 3            Unf             0          968            968    GasA         TA
# 4            Unf             0          785           1394    GasA         Gd
#
#   central_air electrical  1st_flr_sf
# ...

# %%
test_3.shape
# Out:
# (878, 15)

# %%
test_3.dtypes
# Out:
# foundation        object
# bsmt_qual         object
# bsmt_cond         object
# bsmt_exposure     object
# bsmtfin_type_1    object
# bsmtfin_sf_1       int64
# bsmtfin_type_2    object
# bsmtfin_sf_2       int64
# bsmt_unf_sf        int64
# total_bsmt_sf      int64
# heating           object
# heating_qc        object
# central_air       object
# electrical        object
# 1st_flr_sf         int64
# dtype: object

# %%
test_3.describe(include = 'all')
# Out:
#        foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# count         878       853       853           853            853
# unique          6         5         3             4              6
# top         PConc        TA        TA            No            Unf
# freq          383       396       781           567            248
# mean          NaN       NaN       NaN           NaN            NaN
# std           NaN       NaN       NaN           NaN            NaN
# min           NaN       NaN       NaN           NaN            NaN
# 25%           NaN       NaN       NaN           NaN            NaN
# 50%           NaN       NaN       NaN           NaN            NaN
# 75%           NaN       NaN       NaN           NaN            NaN
# max           NaN       NaN       NaN           NaN            NaN
#
#         bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# count     878.000000            853    878.000000   878.000000     878.000000
# ...

# %%
test_3.isna().sum()
# Out:
# foundation         0
# bsmt_qual         25
# bsmt_cond         25
# bsmt_exposure     25
# bsmtfin_type_1    25
# bsmtfin_sf_1       0
# bsmtfin_type_2    25
# bsmtfin_sf_2       0
# bsmt_unf_sf        0
# total_bsmt_sf      0
# heating            0
# heating_qc         0
# central_air        0
# electrical         1
# 1st_flr_sf         0
# dtype: int64

# %%
test['bsmt_qual'].fillna('None', inplace=True)
test['bsmt_cond'].fillna('None', inplace=True)
test['bsmt_exposure'].fillna('None', inplace=True)
test['bsmtfin_type_1'].fillna('None', inplace=True)
test['bsmtfin_type_2'].fillna('None', inplace=True)
test['electrical'].fillna('SBrkr', inplace=True)

# %%
test[['bsmt_qual', 'bsmt_cond', 'bsmt_exposure','bsmtfin_type_1','bsmtfin_type_2',
       'electrical']].isna().sum()
# Out:
# bsmt_qual         0
# bsmt_cond         0
# bsmt_exposure     0
# bsmtfin_type_1    0
# bsmtfin_type_2    0
# electrical        0
# dtype: int64

# %%
test['central_air'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
# make "central_air" binary values
test['central_air'] = test['central_air'].replace({'Y':1 , 'N':0})
test['central_air'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: central_air, dtype: int64

# %% [markdown]
# ##### Test_4

# %%
test_4 =test.iloc[:,45:60]
test_4.head()
# Out:
#    2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  \
# 0        1020                0         1928               0               0
# 1           0                0         1967               0               0
# 2         832                0         1496               1               0
# 3           0                0          968               0               0
# 4           0                0         1394               1               0
#
#    full_bath  half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  \
# 0          2          0              4              2           Fa
# 1          2          0              6              2           TA
# 2          2          1              3              1           Gd
# 3          1          0              2              1           TA
# 4          1          1              3              1           TA
#
#    totrms_abvgrd functional  fireplaces fireplace_qu garage_type
# ...

# %%
test_4.shape
# Out:
# (878, 15)

# %%
test_4.dtypes
# Out:
# 2nd_flr_sf          int64
# low_qual_fin_sf     int64
# gr_liv_area         int64
# bsmt_full_bath      int64
# bsmt_half_bath      int64
# full_bath           int64
# half_bath           int64
# bedroom_abvgr       int64
# kitchen_abvgr       int64
# kitchen_qual       object
# totrms_abvgrd       int64
# functional         object
# fireplaces          int64
# fireplace_qu       object
# garage_type        object
# dtype: object

# %%
test_4.describe(include='all')
# Out:
#          2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# count    878.000000       878.000000   878.000000      878.000000
# unique          NaN              NaN          NaN             NaN
# top             NaN              NaN          NaN             NaN
# freq            NaN              NaN          NaN             NaN
# mean     348.398633         2.728929  1496.914579        0.439636
# std      432.985566        32.572548   506.468967        0.529948
# min        0.000000         0.000000   407.000000        0.000000
# 25%        0.000000         0.000000  1114.000000        0.000000
# 50%        0.000000         0.000000  1436.000000        0.000000
# 75%      720.000000         0.000000  1779.000000        1.000000
# max     2065.000000       481.000000  4476.000000        2.000000
#
#         bsmt_half_bath   full_bath   half_bath  bedroom_abvgr  kitchen_abvgr  \
# count       878.000000  878.000000  878.000000     878.000000     878.000000
# ...

# %%
test_4.isna().sum()
# Out:
# 2nd_flr_sf           0
# low_qual_fin_sf      0
# gr_liv_area          0
# bsmt_full_bath       0
# bsmt_half_bath       0
# full_bath            0
# half_bath            0
# bedroom_abvgr        0
# kitchen_abvgr        0
# kitchen_qual         0
# totrms_abvgrd        0
# functional           0
# fireplaces           0
# fireplace_qu       422
# garage_type         44
# dtype: int64

# %%
test['fireplace_qu'].fillna('None', inplace=True)
test['garage_type'].fillna('None', inplace=True)

# %%
test[['fireplace_qu','garage_type']].isna().sum()
# Out:
# fireplace_qu    0
# garage_type     0
# dtype: int64

# %% [markdown]
# ##### Test_5

# %%
test_5 = test.iloc[:,60:75]
test_5.head()
# Out:
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 0         1910.0           Unf            1          440          Po
# 1         1977.0           Fin            2          580          TA
# 2         2006.0           RFn            2          426          TA
# 3         1935.0           Unf            2          480          Fa
# 4         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 0          Po           Y             0             60             112
# 1          TA           Y           170              0               0
# 2          TA           Y           100             24               0
# 3          TA           N             0              0             184
# 4          TA           Y             0             76               0
#
#    3ssn_porch  screen_porch  pool_area pool_qc fence
# 0           0             0          0     NaN   NaN
# ...

# %%
test_5.shape
# Out:
# (878, 15)

# %%
test_5.dtypes
# Out:
# garage_yr_blt     float64
# garage_finish      object
# garage_cars         int64
# garage_area         int64
# garage_qual        object
# garage_cond        object
# paved_drive        object
# wood_deck_sf        int64
# open_porch_sf       int64
# enclosed_porch      int64
# 3ssn_porch          int64
# screen_porch        int64
# pool_area           int64
# pool_qc            object
# fence              object
# dtype: object

# %%
test_5.describe(include = 'all')
# Out:
#         garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# count      833.000000           833   878.000000   878.000000         833
# unique            NaN             3          NaN          NaN           4
# top               NaN           Unf          NaN          NaN          TA
# freq              NaN           382          NaN          NaN         782
# mean      1976.759904           NaN     1.742597   470.362187         NaN
# std         25.689763           NaN     0.750391   212.734075         NaN
# min       1900.000000           NaN     0.000000     0.000000         NaN
# 25%       1960.000000           NaN     1.000000   322.500000         NaN
# 50%       1978.000000           NaN     2.000000   473.000000         NaN
# 75%       2001.000000           NaN     2.000000   576.000000         NaN
# max       2010.000000           NaN     4.000000  1488.000000         NaN
#
#        garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# ...

# %%
test_5.isna().sum()
# Out:
# garage_yr_blt      45
# garage_finish      45
# garage_cars         0
# garage_area         0
# garage_qual        45
# garage_cond        45
# paved_drive         0
# wood_deck_sf        0
# open_porch_sf       0
# enclosed_porch      0
# 3ssn_porch          0
# screen_porch        0
# pool_area           0
# pool_qc           874
# fence             706
# dtype: int64

# %%
test['garage_yr_blt'].fillna(1978, inplace=True)
test['garage_finish'].fillna('None', inplace=True)
test['garage_qual'].fillna('None', inplace=True)
test['garage_cond'].fillna('None', inplace=True)
test['pool_qc'].fillna('None', inplace=True)
test['fence'].fillna('None', inplace=True)

# %%
test[['garage_yr_blt', 'garage_finish', 'garage_qual', 'garage_cond',
       'pool_qc', 'fence']].isna().sum()
# Out:
# garage_yr_blt    0
# garage_finish    0
# garage_qual      0
# garage_cond      0
# pool_qc          0
# fence            0
# dtype: int64

# %% [markdown]
# ##### Test_6

# %%
test_6 = test.iloc[:,75:80]
test_6.head()
# Out:
#   misc_feature  misc_val  mo_sold  yr_sold sale_type
# 0          NaN         0        4     2006       WD
# 1          NaN         0        8     2006       WD
# 2          NaN         0        9     2006       New
# 3          NaN         0        7     2007       WD
# 4          NaN         0        7     2009       WD

# %%
test_6.dtypes
# Out:
# misc_feature    object
# misc_val         int64
# mo_sold          int64
# yr_sold          int64
# sale_type       object
# dtype: object

# %%
test_6.describe(include='all')
# Out:
#        misc_feature      misc_val     mo_sold      yr_sold sale_type
# count            41    878.000000  878.000000   878.000000       878
# unique            3           NaN         NaN          NaN        10
# top            Shed           NaN         NaN          NaN       WD
# freq             39           NaN         NaN          NaN       755
# mean            NaN     48.498861    6.202733  2007.825740       NaN
# std             NaN    550.169317    2.642498     1.327861       NaN
# min             NaN      0.000000    1.000000  2006.000000       NaN
# 25%             NaN      0.000000    5.000000  2007.000000       NaN
# 50%             NaN      0.000000    6.000000  2008.000000       NaN
# 75%             NaN      0.000000    8.000000  2009.000000       NaN
# max             NaN  15500.000000   12.000000  2010.000000       NaN

# %%
test_6.isna().sum()
# Out:
# misc_feature    837
# misc_val          0
# mo_sold           0
# yr_sold           0
# sale_type         0
# dtype: int64

# %%
test['misc_feature'].fillna('None', inplace=True)

# %%
test['misc_feature'].isna().sum()
# Out:
# 0

# %%
test.isna().sum()
# Out:
# id              0
# pid             0
# ms_subclass     0
# ms_zoning       0
# lot_frontage    0
#                ..
# misc_feature    0
# misc_val        0
# mo_sold         0
# yr_sold         0
# sale_type       0
# Length: 80, dtype: int64

# %%
test.to_csv('../Data/test_clean.csv', index=False)
