# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from scipy import stats

# %%
house = pd.read_csv('../Data/train_clean.csv')
house.head()
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area  street  \
# 0  109  533352170           60        RL           0.0     13517       0
# 1  544  531379050           60        RL          43.0     11492       0
# 2  153  535304180           20        RL          68.0      7922       0
# 3  318  916386060           60        RL          73.0      9802       0
# 4  255  906425045           50        RL          82.0     14235       0
#
#   alley lot_shape land_contour  ... screen_porch pool_area pool_qc fence  \
# 0     0       IR1          Lvl  ...            0         0    None  None
# 1     0       IR1          Lvl  ...            0         0    None  None
# 2     0       Reg          Lvl  ...            0         0    None  None
# 3     0       Reg          Lvl  ...            0         0    None  None
# 4     0       IR1          Lvl  ...            0         0    None  None
#
#   misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 0         None        0       3    2010        WD      130500
# 1         None        0       4    2009        WD      220000
# 2         None        0       1    2010        WD      109000
# 3         None        0       4    2010        WD      174000
# 4         None        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %%
test = pd.read_csv('../Data/test_clean.csv')
test.head()
# Out:
#      id        pid  ms_subclass ms_zoning  lot_frontage  lot_area  street  \
# 0  2658  902301120          190        RM          69.0      9142       0
# 1  2718  905108090           90        RL           0.0      9662       0
# 2  2414  528218130           60        RL          58.0     17104       0
# 3  1989  902207150           30        RM          60.0      8520       0
# 4   625  535105100           20        RL           0.0      9500       0
#
#   alley lot_shape land_contour  ... 3ssn_porch screen_porch pool_area pool_qc  \
# 0  Grvl       Reg          Lvl  ...          0            0         0    None
# 1     0       IR1          Lvl  ...          0            0         0    None
# 2     0       IR1          Lvl  ...          0            0         0    None
# 3     0       Reg          Lvl  ...          0            0         0    None
# 4     0       IR1          Lvl  ...          0          185         0    None
#
#   fence misc_feature misc_val mo_sold  yr_sold  sale_type
# 0  None         None        0       4     2006        WD
# 1  None         None        0       8     2006        WD
# 2  None         None        0       9     2006        New
# 3  None         None        0       7     2007        WD
# 4  None         None        0       7     2009        WD
#
# [5 rows x 80 columns]

# %%
test.shape
# Out:
# (878, 80)

# %%
house.shape
# Out:
# (2051, 81)

# %%
xcols = ['overall_qual', 'total_bsmt_sf', '1st_flr_sf', 'gr_liv_area', 'garage_cars', 'garage_area']

# %%
house_types = house[xcols]
house_types.head()
# Out:
#    overall_qual  total_bsmt_sf  1st_flr_sf  gr_liv_area  garage_cars  \
# 0             6          725.0         725         1479          2.0
# 1             7          913.0         913         2122          2.0
# 2             5         1057.0        1057         1057          1.0
# 3             5          384.0         744         1444          2.0
# 4             6          676.0         831         1445          2.0
#
#    garage_area
# 0        475.0
# 1        559.0
# 2        246.0
# 3        400.0
# 4        484.0

# %%
house_types.dtypes
# Out:
# overall_qual       int64
# total_bsmt_sf    float64
# 1st_flr_sf         int64
# gr_liv_area        int64
# garage_cars      float64
# garage_area      float64
# dtype: object

# %%
house_types.describe()
# Out:
#        overall_qual  total_bsmt_sf   1st_flr_sf  gr_liv_area  garage_cars  \
# count   2051.000000    2051.000000  2051.000000  2051.000000  2051.000000
# mean       6.112140    1057.471965  1164.488055  1499.330083     1.775719
# std        1.426271     449.908003   396.446923   500.447829     0.765357
# min        1.000000       0.000000   334.000000   334.000000     0.000000
# 25%        5.000000     793.000000   879.500000  1129.000000     1.000000
# 50%        6.000000     994.000000  1093.000000  1444.000000     2.000000
# 75%        7.000000    1318.500000  1405.000000  1728.500000     2.000000
# max       10.000000    6110.000000  5095.000000  5642.000000     5.000000
#
#        garage_area
# count  2051.000000
# mean    473.440761
# std     216.135102
# min       0.000000
# 25%     319.000000
# 50%     480.000000
# 75%     576.000000
# max    1418.000000

# %%
house_types.isna().sum()
# Out:
# overall_qual     0
# total_bsmt_sf    0
# 1st_flr_sf       0
# gr_liv_area      0
# garage_cars      0
# garage_area      0
# dtype: int64

# %%
X = house[xcols]
y = house['saleprice']

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.3, random_state=1222)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (1435, 6) (1435,)

# %%
print(X_val.shape, y_val.shape)
# Out:
# (616, 6) (616,)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train, y_train)
# Out:
# 0.7729453689039859

# %%
lr.score(X_val, y_val)
# The model looks like it fits well
# Out:
# 0.787933961442823

# %%
X_dummies.dtypes

# %%
preds = lr.predict(test[xcols])

# %%
test.rename(columns={'id': 'Id'}, inplace=True)

# %%
test['SalePrice'] = preds
test.head()
# Out:
#      Id        pid  ms_subclass ms_zoning  lot_frontage  lot_area  street  \
# 0  2658  902301120          190        RM          69.0      9142       0
# 1  2718  905108090           90        RL           0.0      9662       0
# 2  2414  528218130           60        RL          58.0     17104       0
# 3  1989  902207150           30        RM          60.0      8520       0
# 4   625  535105100           20        RL           0.0      9500       0
#
#   alley lot_shape land_contour  ... screen_porch pool_area pool_qc fence  \
# 0  Grvl       Reg          Lvl  ...            0         0    None  None
# 1     0       IR1          Lvl  ...            0         0    None  None
# 2     0       IR1          Lvl  ...            0         0    None  None
# 3     0       Reg          Lvl  ...            0         0    None  None
# 4     0       IR1          Lvl  ...          185         0    None  None
#
#   misc_feature misc_val mo_sold yr_sold  sale_type      SalePrice
# 0         None        0       4    2006        WD   184605.383214
# 1         None        0       8    2006        WD   211149.830198
# 2         None        0       9    2006        New  185882.495675
# 3         None        0       7    2007        WD   129986.943957
# 4         None        0       7    2009        WD   187952.037724
#
# [5 rows x 81 columns]

# %%
submission_2 = test[['Id', 'SalePrice']].set_index('Id')

# %%
submission_2.head()
# Out:
#           SalePrice
# Id
# 2658  184605.383214
# 2718  211149.830198
# 2414  185882.495675
# 1989  129986.943957
# 625   187952.037724

# %%
submission_2.shape
# Out:
# (878, 1)

# %%
#submission_2.to_csv('juddy_submit_2.csv')
